# %% [markdown]
# # Propósito
#
# O objetivo nesse projeto é produzir visualizações abrangentes e confiáveis das ações da Tesla possibilitando assim um acompanhamento dinâmico do movimento de suas ações ao logo do tempo.
# Além disso, nesse projeto também é necessário desenvolver e disponibilizar um modelo preditivo utilizando técnicas avançadas como redes neurais LSTM para prever com precisão próximos movimentos de mercado da empresa.

# %%
from plots import prepara_dados
import yfinance as yf
import pandas as pd
import numpy as np
from seaborn import despine, barplot
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, GRU, Dropout
from sklearn.preprocessing import MinMaxScaler
from joblib import dump

# %%
download = yf.download("TSLA", start="2022-01-01", end="2025-03-25", multi_level_index=False)
download
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Close        High         Low        Open     Volume
# Date
# 2022-01-03  399.926666  400.356659  378.679993  382.583344  103931400
# 2022-01-04  383.196655  402.666656  374.350006  396.516663  100248300
# 2022-01-05  362.706665  390.113342  360.336670  382.216675   80119800
# 2022-01-06  354.899994  362.666656  340.166656  359.000000   90336600
# 2022-01-07  342.320007  360.309998  336.666656  360.123322   84164700
# ...                ...         ...         ...         ...        ...
# 2025-03-18  225.309998  230.100006  222.279999  228.160004  111477600
# 2025-03-19  235.860001  241.410004  229.199997  231.610001  111993800
# 2025-03-20  236.259995  238.000000  230.050003  233.350006   99028300
# 2025-03-21  248.710007  249.520004  234.550003  234.990005  132728700
# 2025-03-24  278.390015  278.640015  256.329987  258.079987  169079900
#
# [808 rows x 5 columns]

# %%
data = pd.DataFrame(download)
data.head()
# Out:
#                  Close        High         Low        Open     Volume
# Date
# 2022-01-03  399.926666  400.356659  378.679993  382.583344  103931400
# 2022-01-04  383.196655  402.666656  374.350006  396.516663  100248300
# 2022-01-05  362.706665  390.113342  360.336670  382.216675   80119800
# 2022-01-06  354.899994  362.666656  340.166656  359.000000   90336600
# 2022-01-07  342.320007  360.309998  336.666656  360.123322   84164700

# %%
data.tail(10)
# Out:
#                  Close        High         Low        Open     Volume
# Date
# 2025-03-11  230.580002  237.059998  217.020004  225.309998  174896400
# 2025-03-12  248.089996  251.839996  241.100006  247.220001  142215700
# 2025-03-13  240.679993  248.289993  232.600006  248.130005  114813500
# 2025-03-14  249.979996  251.580002  240.729996  247.309998  100242300
# 2025-03-17  238.009995  245.399994  232.800003  245.059998  111900600
# 2025-03-18  225.309998  230.100006  222.279999  228.160004  111477600
# 2025-03-19  235.860001  241.410004  229.199997  231.610001  111993800
# 2025-03-20  236.259995  238.000000  230.050003  233.350006   99028300
# 2025-03-21  248.710007  249.520004  234.550003  234.990005  132728700
# 2025-03-24  278.390015  278.640015  256.329987  258.079987  169079900

# %%
data.to_csv("Acoes_Tesla.csv")

# %%
print(isinstance(data.columns, pd.MultiIndex))
# Out:
# False

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Close, High, Low, Open, Volume]
# Index: []

# %%
data.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
data.isnull().sum()
# Out:
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
data_grafico = data.iloc[501:,:]
data_grafico.head()
# Out:
#                  Close        High         Low        Open     Volume
# Date
# 2024-01-02  248.419998  251.250000  244.410004  250.080002  104654200
# 2024-01-03  238.449997  245.679993  236.320007  244.979996  121082600
# 2024-01-04  237.929993  242.699997  237.729996  239.250000  102629300
# 2024-01-05  237.490005  240.119995  234.899994  236.860001   92379400
# 2024-01-08  240.449997  241.250000  235.300003  236.139999   85166600

# %% [markdown]
# ## Visualizações

# %%
plt.figure(figsize=(18,6))
plt.plot(data_grafico.index, data_grafico["Close"])
plt.title("Ações da Tesla: 2024/2025", fontweight="bold", fontsize=18)
plt.xlabel("Data", fontweight="bold", fontsize=13)
plt.ylabel("Valor das Ações ($)", fontweight="bold", fontsize=13)
plt.annotate(text="As ações da Tesla tiveram uma valorização massiva em seu valor de mercado \
            \nno mês de Janeiro de 2025 chegando a dobrar de Valor porém de Fevereiro à Março \
            \nperdeu praticamente toda essa valorização", xy=(0.7, 0.2), xycoords="figure fraction",
             xytext=(0.1,0.65), fontsize=12, fontweight="bold", color="#4C72B0")
despine(right=True, top=True)
plt.show()

# %%
plt.figure(figsize=(18,6))
suavizacao = data_grafico[["Close"]].ewm(span=12, method="single").mean()
plt.plot(suavizacao)
plt.title("Tendências históricas:Ações da Tesla", fontweight="bold", fontsize=18)
plt.xlabel("Data", fontweight="bold", fontsize=13)
plt.ylabel("Valor das Ações ($)", fontweight="bold", fontsize=13)
plt.annotate(text="Essa visualização suaviza os 'ruídos não relevantes' tornando a identificação das tendências\
            \nmuito mais fáceis e consistentes além de bem mais confiáveis", xy=(0.7, 0.2), xycoords="figure fraction",
             xytext=(0.08,0.65), fontsize=12, fontweight="bold", color="#4C72B0")
despine(right=True, top=True)

# %%
data_volume = data_grafico.resample("MS")[["Volume"]].mean()
data_volume.head()
# Out:
#                   Volume
# Date
# 2024-01-01  1.116088e+08
# 2024-02-01  1.009954e+08
# 2024-03-01  9.494521e+07
# 2024-04-01  1.126609e+08
# 2024-05-01  7.582640e+07

# %%
plt.figure(figsize=(17,6))
barplot(data=data_volume, x=data_volume.index.strftime("%d-%m-%Y"), y=data_volume["Volume"], width=0.7, color="#4C72B0")
plt.title("Volume Médio de Negociações ", fontsize=18, fontweight="bold")
plt.xlabel("Data", fontsize=12, fontweight="bold")
plt.ylabel("Valor", fontsize=12, fontweight="bold")
despine(right=True, top=True)
plt.show()

# %% [markdown]
# ## Preparação dos dados

# %%
data.shape
# Out:
# (808, 5)

# %%
ready_data = np.reshape(data["Close"], (-1,1))
ready_data[:10]
# Out:
# array([[399.92666626],
#        [383.19665527],
#        [362.70666504],
#        [354.8999939 ],
#        [342.32000732],
#        [352.70666504],
#        [354.79998779],
#        [368.73999023],
#        [343.85333252],
#        [349.86999512]])

# %%
ready_data.shape
# Out:
# (808, 1)

# %%
scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(ready_data)
ready_data = scaler.transform(ready_data)
ready_data[:20]
# Out:
# array([[ 0.56997352],
#        [ 0.47996915],
#        [ 0.3697368 ],
#        [ 0.32773835],
#        [ 0.26006035],
#        [ 0.31593864],
#        [ 0.32720033],
#        [ 0.40219497],
#        [ 0.26830935],
#        [ 0.30067788],
#        [ 0.26642638],
#        [ 0.20391296],
#        [ 0.20502478],
#        [ 0.11111115],
#        [ 0.08618468],
#        [ 0.06538272],
#        [ 0.09947283],
#        [-0.09475642],
#        [-0.06382249],
#        [ 0.09823542]])

# %%
#Função prepara dados vem do arquivo plots
X,y = prepara_dados(ready_data)

# %%
X.shape
# Out:
# (748, 60)

# %%
print(len(ready_data))
print(len(data))
# Out:
# 808
# 808

# %%
data.shape[0]
# Out:
# 808

# %%
# Função para separação dos dados para treino, teste e validação
def separa_dados(X, y):
    length_treino = int(len(data) * 0.75) # 75% para teste
    length_val = int(len(data) * 0.85)

    #Separação das variáveis independentes
    X_train = X[: length_treino] # Variáveis independentes treino
    X_val = X[length_treino: length_val] # Variáveis independentes validação
    X_test = X[length_val :]  # Variáveis independentes teste

    #Separação das variáveis dependentes
    y_train = y[: length_treino] # Variável dependente treino     
    y_val = y[length_treino: length_val] # Variável dependente validação
    y_test = y[length_val :]  # Variável dependente teste
    index_test = data.index[length_val :]
    
    return X_train, X_val, X_test, y_train, y_val, y_test, index_test[60:]
    
X_train, X_val, X_test, y_train, y_val, y_test, index_test = separa_dados(X,y)
X_train.shape
# Out:
# (606, 60)

# %% [markdown]
# Dimensões dos dados de Validação e teste após separação

# %%
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
print(index_test.shape)
# Out:
# (80, 60)
# (80,)
# (62, 60)
# (62,)
# (62,)

# %%
index_test[-1]
# Out:
# Timestamp('2025-03-24 00:00:00')

# %%
#Redimensionamento dos dados para formato aceito pela rede neural
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))
X_train.shape
# Out:
# (606, 60, 1)

# %% [markdown]
# ## Rede Neural LSTM

# %%
modelo_lstm = Sequential()
modelo_lstm.add(LSTM(100, return_sequences=True, input_shape=(X_train.shape[1],1)))
modelo_lstm.add(Dropout(0.2))
modelo_lstm.add(LSTM(100, return_sequences=True))
modelo_lstm.add(Dropout(0.2))
modelo_lstm.add(LSTM(100, return_sequences=True))
modelo_lstm.add(Dropout(0.2))
modelo_lstm.add(LSTM(100, return_sequences=False))
modelo_lstm.add(Dropout(0.2))
modelo_lstm.add(Dense(1))
# Out:
# C:\Users\roni_\anaconda3\envs\ambiente_streamlit\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
modelo_lstm.compile(optimizer="adam", loss="mean_squared_error")
modelo_lstm.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 60, 100)        │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 60, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 60, 100)        │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 60, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 60, 100)        │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 60, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 100)            │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 282,101 (1.08 MB)
#  Trainable params: 282,101 (1.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
es = EarlyStopping(monitor="val_loss", patience=40, restore_best_weights=True) #EarlyStopping para evitar overfitting
historico = modelo_lstm.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_val, y_val), callbacks=es)
# Out:
# Epoch 1/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - loss: 0.0994 - val_loss: 0.1064
# Epoch 2/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0300 - val_loss: 0.0817
# Epoch 3/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0211 - val_loss: 0.0685
# Epoch 4/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0155 - val_loss: 0.0560
# Epoch 5/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.0131 - val_loss: 0.0496
# Epoch 6/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0131 - val_loss: 0.0486
# Epoch 7/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0113 - val_loss: 0.0425
# Epoch 8/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0096 - val_loss: 0.0415
# Epoch 9/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0103 - val_loss: 0.0370
# Epoch 10/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0099 - val_loss: 0.0333
# Epoch 11/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0086 - val_loss: 0.0360
# Epoch 12/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0079 - val_loss: 0.0293
# Epoch 13/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0083 - val_loss: 0.0319
# Epoch 14/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0091 - val_loss: 0.0278
# Epoch 15/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.0067 - val_loss: 0.0266
# Epoch 16/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0063 - val_loss: 0.0329
# Epoch 17/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0072 - val_loss: 0.0254
# Epoch 18/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0069 - val_loss: 0.0237
# Epoch 19/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0068 - val_loss: 0.0291
# Epoch 20/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 0.0070 - val_loss: 0.0200
# Epoch 21/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0068 - val_loss: 0.0242
# Epoch 22/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0084 - val_loss: 0.0258
# Epoch 23/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0072 - val_loss: 0.0246
# Epoch 24/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0062 - val_loss: 0.0236
# Epoch 25/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 0.0065 - val_loss: 0.0216
# Epoch 26/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0063 - val_loss: 0.0183
# Epoch 27/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0060 - val_loss: 0.0201
# Epoch 28/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 0.0055 - val_loss: 0.0202
# Epoch 29/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.0058 - val_loss: 0.0217
# Epoch 30/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0058 - val_loss: 0.0198
# Epoch 31/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0055 - val_loss: 0.0204
# Epoch 32/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0051 - val_loss: 0.0169
# Epoch 33/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0063 - val_loss: 0.0177
# Epoch 34/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0053 - val_loss: 0.0180
# Epoch 35/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.0055 - val_loss: 0.0191
# Epoch 36/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0055 - val_loss: 0.0199
# Epoch 37/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0054 - val_loss: 0.0167
# Epoch 38/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0047 - val_loss: 0.0183
# Epoch 39/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0057 - val_loss: 0.0140
# Epoch 40/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0044 - val_loss: 0.0174
# Epoch 41/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0046 - val_loss: 0.0142
# Epoch 42/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 0.0045 - val_loss: 0.0147
# Epoch 43/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0047 - val_loss: 0.0126
# Epoch 44/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0055 - val_loss: 0.0137
# Epoch 45/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0045 - val_loss: 0.0146
# Epoch 46/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0039 - val_loss: 0.0166
# Epoch 47/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0045 - val_loss: 0.0146
# Epoch 48/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0042 - val_loss: 0.0149
# Epoch 49/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0041 - val_loss: 0.0142
# Epoch 50/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0042 - val_loss: 0.0100
# Epoch 51/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0042 - val_loss: 0.0129
# Epoch 52/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0041 - val_loss: 0.0164
# Epoch 53/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0041 - val_loss: 0.0143
# Epoch 54/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0040 - val_loss: 0.0121
# Epoch 55/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0035 - val_loss: 0.0104
# Epoch 56/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 0.0041 - val_loss: 0.0128
# Epoch 57/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0037 - val_loss: 0.0149
# Epoch 58/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0036 - val_loss: 0.0102
# Epoch 59/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0037 - val_loss: 0.0105
# Epoch 60/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 0.0037 - val_loss: 0.0105
# Epoch 61/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0037 - val_loss: 0.0100
# Epoch 62/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0036 - val_loss: 0.0100
# Epoch 63/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0038 - val_loss: 0.0102
# Epoch 64/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 0.0036 - val_loss: 0.0094
# Epoch 65/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0037 - val_loss: 0.0109
# Epoch 66/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0038 - val_loss: 0.0093
# Epoch 67/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0037 - val_loss: 0.0088
# Epoch 68/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0037 - val_loss: 0.0079
# Epoch 69/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0037 - val_loss: 0.0084
# Epoch 70/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0035 - val_loss: 0.0086
# Epoch 71/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0029 - val_loss: 0.0080
# Epoch 72/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - loss: 0.0035 - val_loss: 0.0087
# Epoch 73/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.0033 - val_loss: 0.0090
# Epoch 74/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.0032 - val_loss: 0.0083
# Epoch 75/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0033 - val_loss: 0.0093
# Epoch 76/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 0.0033 - val_loss: 0.0095
# Epoch 77/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0032 - val_loss: 0.0099
# Epoch 78/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0031 - val_loss: 0.0098
# Epoch 79/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0028 - val_loss: 0.0082
# Epoch 80/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0028 - val_loss: 0.0108
# Epoch 81/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0029 - val_loss: 0.0080
# Epoch 82/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 0.0029 - val_loss: 0.0060
# Epoch 83/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 84/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0037 - val_loss: 0.0073
# Epoch 85/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 0.0025 - val_loss: 0.0076
# Epoch 86/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0032 - val_loss: 0.0096
# Epoch 87/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.0033 - val_loss: 0.0076
# Epoch 88/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0029 - val_loss: 0.0087
# Epoch 89/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0027 - val_loss: 0.0110
# Epoch 90/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0029 - val_loss: 0.0088
# Epoch 91/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0033 - val_loss: 0.0078
# Epoch 92/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0030 - val_loss: 0.0101
# Epoch 93/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0030 - val_loss: 0.0099
# Epoch 94/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0031 - val_loss: 0.0092
# Epoch 95/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.0032 - val_loss: 0.0068
# Epoch 96/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0027 - val_loss: 0.0085
# Epoch 97/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0028 - val_loss: 0.0065
# Epoch 98/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0029 - val_loss: 0.0092
# Epoch 99/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0033 - val_loss: 0.0074
# Epoch 100/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 0.0032 - val_loss: 0.0078
# Epoch 101/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0026 - val_loss: 0.0070
# Epoch 102/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 0.0034 - val_loss: 0.0088
# Epoch 103/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0031 - val_loss: 0.0077
# Epoch 104/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0031 - val_loss: 0.0066
# Epoch 105/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0031 - val_loss: 0.0090
# Epoch 106/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0038 - val_loss: 0.0067
# Epoch 107/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0029 - val_loss: 0.0056
# Epoch 108/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0027 - val_loss: 0.0083
# Epoch 109/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0032 - val_loss: 0.0076
# Epoch 110/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.0032 - val_loss: 0.0069
# Epoch 111/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0028 - val_loss: 0.0083
# Epoch 112/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0028 - val_loss: 0.0085
# Epoch 113/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0032 - val_loss: 0.0091
# Epoch 114/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0029 - val_loss: 0.0074
# Epoch 115/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0035 - val_loss: 0.0083
# Epoch 116/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0033 - val_loss: 0.0076
# Epoch 117/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0030 - val_loss: 0.0073
# Epoch 118/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 119/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0028 - val_loss: 0.0090
# Epoch 120/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0032 - val_loss: 0.0072
# Epoch 121/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0026 - val_loss: 0.0089
# Epoch 122/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0030 - val_loss: 0.0068
# Epoch 123/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0024 - val_loss: 0.0056
# Epoch 124/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0025 - val_loss: 0.0075
# Epoch 125/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0032 - val_loss: 0.0086
# Epoch 126/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0028 - val_loss: 0.0108
# Epoch 127/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0032 - val_loss: 0.0083
# Epoch 128/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0029 - val_loss: 0.0101
# Epoch 129/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0027 - val_loss: 0.0087
# Epoch 130/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0028 - val_loss: 0.0087
# Epoch 131/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0027 - val_loss: 0.0095
# Epoch 132/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0025 - val_loss: 0.0065
# Epoch 133/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0030 - val_loss: 0.0060
# Epoch 134/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0033 - val_loss: 0.0098
# Epoch 135/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0029 - val_loss: 0.0055
# Epoch 136/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0030 - val_loss: 0.0066
# Epoch 137/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0030 - val_loss: 0.0070
# Epoch 138/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0025 - val_loss: 0.0072
# Epoch 139/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0026 - val_loss: 0.0074
# Epoch 140/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0029 - val_loss: 0.0079
# Epoch 141/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0029 - val_loss: 0.0101
# Epoch 142/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0025 - val_loss: 0.0144
# Epoch 143/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0029 - val_loss: 0.0131
# Epoch 144/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0029 - val_loss: 0.0065
# Epoch 145/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0032 - val_loss: 0.0068
# Epoch 146/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0027 - val_loss: 0.0095
# Epoch 147/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0027 - val_loss: 0.0097
# Epoch 148/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0030 - val_loss: 0.0123
# Epoch 149/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0028 - val_loss: 0.0101
# Epoch 150/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0031 - val_loss: 0.0112
# Epoch 151/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0030 - val_loss: 0.0073
# Epoch 152/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0032 - val_loss: 0.0066
# Epoch 153/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0029 - val_loss: 0.0078
# Epoch 154/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0031 - val_loss: 0.0082
# Epoch 155/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0030 - val_loss: 0.0060
# Epoch 156/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0027 - val_loss: 0.0062
# Epoch 157/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0025 - val_loss: 0.0055
# Epoch 158/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.0031 - val_loss: 0.0057

# %%
plt.figure(figsize=(14,5))
plt.plot(historico.history["loss"])
plt.title("Evolução da Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
y_pred_lstm = modelo_lstm.predict(X_test)
y_pred_lstm[:10]
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DFF845A160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DFF845A160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# array([[0.76182616],
#        [0.6844713 ],
#        [0.6823017 ],
#        [0.7899854 ],
#        [0.8482617 ],
#        [0.78984594],
#        [0.6894624 ],
#        [0.5985158 ],
#        [0.4933619 ],
#        [0.5423665 ]], dtype=float32)

# %%
y_pred_lstm = np.reshape(y_pred_lstm, (-1,1))
y_test = np.reshape(y_test, (-1,1))
y_pred_lstm = scaler.inverse_transform(y_pred_lstm)
y_test = scaler.inverse_transform(y_test)

# %%
plt.figure(figsize=(16,6))
plt.plot(index_test, y_test, label="Dados Originais")
plt.plot(index_test, y_pred_lstm, label="Previsão do Modelo")
plt.title("Previsões Redes Neurais LSTM", fontsize=16, fontweight="bold")
plt.xlabel("Data", fontsize=12, fontweight="bold")
plt.ylabel("Valor das Ações", fontsize=12, fontweight="bold")
plt.legend()
plt.show()

# %%
modelo_lstm.save("Modelo_treinado_lstm.keras")

# %% [markdown]
# ## Rede Neural GRU

# %%
modelo_gru = Sequential()
modelo_gru.add(GRU(100, return_sequences=True, input_shape=(X_train.shape[1],1)))
modelo_gru.add(Dropout(0.2))
modelo_gru.add(GRU(100, return_sequences=True))
modelo_gru.add(Dropout(0.2))
modelo_gru.add(GRU(100, return_sequences=True))
modelo_gru.add(Dropout(0.2))               
modelo_gru.add(GRU(100, return_sequences=False))
modelo_gru.add(Dropout(0.2))               
modelo_gru.add(Dense(1, activation="sigmoid"))
# Out:
# C:\Users\roni_\anaconda3\envs\ambiente_streamlit\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
modelo_gru.compile(optimizer="adam", loss="mean_squared_error")
modelo_gru.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_4 (GRU)                     │ (None, 60, 100)        │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 60, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_5 (GRU)                     │ (None, 60, 100)        │        60,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 60, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_6 (GRU)                     │ (None, 60, 100)        │        60,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 60, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_7 (GRU)                     │ (None, 100)            │        60,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 212,801 (831.25 KB)
#  Trainable params: 212,801 (831.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
historico2 = modelo_gru.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_val, y_val), callbacks=es)
# Out:
# Epoch 1/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - loss: 0.0812 - val_loss: 0.0591
# Epoch 2/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0118 - val_loss: 0.0241
# Epoch 3/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0080 - val_loss: 0.0285
# Epoch 4/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0097 - val_loss: 0.0224
# Epoch 5/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0071 - val_loss: 0.0205
# Epoch 6/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0065 - val_loss: 0.0218
# Epoch 7/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0069 - val_loss: 0.0210
# Epoch 8/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0056 - val_loss: 0.0180
# Epoch 9/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0062 - val_loss: 0.0171
# Epoch 10/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0058 - val_loss: 0.0153
# Epoch 11/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.0055 - val_loss: 0.0171
# Epoch 12/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.0053 - val_loss: 0.0147
# Epoch 13/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0050 - val_loss: 0.0123
# Epoch 14/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0052 - val_loss: 0.0127
# Epoch 15/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.0052 - val_loss: 0.0170
# Epoch 16/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.0053 - val_loss: 0.0115
# Epoch 17/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.0051 - val_loss: 0.0093
# Epoch 18/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 0.0047 - val_loss: 0.0117
# Epoch 19/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 0.0045 - val_loss: 0.0153
# Epoch 20/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0040 - val_loss: 0.0135
# Epoch 21/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.0039 - val_loss: 0.0131
# Epoch 22/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.0039 - val_loss: 0.0130
# Epoch 23/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 0.0044 - val_loss: 0.0130
# Epoch 24/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - loss: 0.0048 - val_loss: 0.0080
# Epoch 25/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0055 - val_loss: 0.0088
# Epoch 26/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0046 - val_loss: 0.0087
# Epoch 27/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.0037 - val_loss: 0.0068
# Epoch 28/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0042 - val_loss: 0.0098
# Epoch 29/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0040 - val_loss: 0.0093
# Epoch 30/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.0038 - val_loss: 0.0070
# Epoch 31/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0038 - val_loss: 0.0103
# Epoch 32/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0038 - val_loss: 0.0110
# Epoch 33/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0037 - val_loss: 0.0075
# Epoch 34/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0033 - val_loss: 0.0097
# Epoch 35/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0030 - val_loss: 0.0084
# Epoch 36/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.0036 - val_loss: 0.0081
# Epoch 37/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0031 - val_loss: 0.0085
# Epoch 38/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0040 - val_loss: 0.0075
# Epoch 39/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 40/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 41/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0029 - val_loss: 0.0064
# Epoch 42/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 43/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0031 - val_loss: 0.0061
# Epoch 44/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 0.0028 - val_loss: 0.0062
# Epoch 45/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0029 - val_loss: 0.0068
# Epoch 46/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0028 - val_loss: 0.0081
# Epoch 47/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0032 - val_loss: 0.0083
# Epoch 48/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0031 - val_loss: 0.0060
# Epoch 49/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.0031 - val_loss: 0.0067
# Epoch 50/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0030 - val_loss: 0.0066
# Epoch 51/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0033 - val_loss: 0.0055
# Epoch 52/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0031 - val_loss: 0.0073
# Epoch 53/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0031 - val_loss: 0.0068
# Epoch 54/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0030 - val_loss: 0.0052
# Epoch 55/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0036 - val_loss: 0.0059
# Epoch 56/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0025 - val_loss: 0.0070
# Epoch 57/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0025 - val_loss: 0.0073
# Epoch 58/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0029 - val_loss: 0.0049
# Epoch 59/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0031 - val_loss: 0.0055
# Epoch 60/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.0029 - val_loss: 0.0055
# Epoch 61/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0033 - val_loss: 0.0058
# Epoch 62/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 0.0028 - val_loss: 0.0052
# Epoch 63/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 0.0033 - val_loss: 0.0097
# Epoch 64/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0029 - val_loss: 0.0085
# Epoch 65/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0029 - val_loss: 0.0054
# Epoch 66/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0029 - val_loss: 0.0087
# Epoch 67/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0029 - val_loss: 0.0066
# Epoch 68/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - loss: 0.0031 - val_loss: 0.0050
# Epoch 69/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0034 - val_loss: 0.0058
# Epoch 70/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0033 - val_loss: 0.0057
# Epoch 71/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0029 - val_loss: 0.0061
# Epoch 72/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0031 - val_loss: 0.0049
# Epoch 73/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0033 - val_loss: 0.0078
# Epoch 74/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0029 - val_loss: 0.0054
# Epoch 75/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.0031 - val_loss: 0.0071
# Epoch 76/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0029 - val_loss: 0.0059
# Epoch 77/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 0.0031 - val_loss: 0.0053
# Epoch 78/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0032 - val_loss: 0.0118
# Epoch 79/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0031 - val_loss: 0.0078
# Epoch 80/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0028 - val_loss: 0.0051
# Epoch 81/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0032 - val_loss: 0.0072
# Epoch 82/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0030 - val_loss: 0.0071
# Epoch 83/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0024 - val_loss: 0.0067
# Epoch 84/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.0028 - val_loss: 0.0063
# Epoch 85/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.0033 - val_loss: 0.0084
# Epoch 86/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0028 - val_loss: 0.0051
# Epoch 87/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0036 - val_loss: 0.0106
# Epoch 88/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0043 - val_loss: 0.0078
# Epoch 89/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0033 - val_loss: 0.0068
# Epoch 90/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0032 - val_loss: 0.0055
# Epoch 91/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0032 - val_loss: 0.0060
# Epoch 92/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0032 - val_loss: 0.0073
# Epoch 93/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 0.0028 - val_loss: 0.0069
# Epoch 94/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - loss: 0.0027 - val_loss: 0.0075
# Epoch 95/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0029 - val_loss: 0.0088
# Epoch 96/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0030 - val_loss: 0.0071
# Epoch 97/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0026 - val_loss: 0.0127
# Epoch 98/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0032 - val_loss: 0.0058
# Epoch 99/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0032 - val_loss: 0.0054
# Epoch 100/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0029 - val_loss: 0.0074
# Epoch 101/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0028 - val_loss: 0.0060
# Epoch 102/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 0.0031 - val_loss: 0.0057
# Epoch 103/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0031 - val_loss: 0.0068
# Epoch 104/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0032 - val_loss: 0.0064
# Epoch 105/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 0.0030 - val_loss: 0.0075
# Epoch 106/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0032 - val_loss: 0.0053
# Epoch 107/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0026 - val_loss: 0.0057
# Epoch 108/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0034 - val_loss: 0.0149
# Epoch 109/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0031 - val_loss: 0.0071
# Epoch 110/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0032 - val_loss: 0.0066
# Epoch 111/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0026 - val_loss: 0.0095
# Epoch 112/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0029 - val_loss: 0.0075

# %%
plt.figure(figsize=(14,5))
plt.plot(historico2.history["loss"])
plt.title("Evolução da Loss (Modelo GRU)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
y_pred = modelo_gru.predict(X_test)
y_pred[:10]
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# array([[0.80959713],
#        [0.7451757 ],
#        [0.761944  ],
#        [0.88257307],
#        [0.89500487],
#        [0.81149024],
#        [0.72927433],
#        [0.6568442 ],
#        [0.54334754],
#        [0.63417476]], dtype=float32)

# %%
y_pred = np.reshape(y_pred, (-1,1))

# %%
y_pred = scaler.inverse_transform(y_pred)

# %%
plt.figure(figsize=(16,6)) #Plotagem do gráfico com pequeno ajuste nos índices para correta visualização
plt.plot(index_test[1:], y_test[:-1], label="Dados Originais")
plt.plot(index_test[1:], y_pred[1:], label="Previsão do Modelo")
plt.title("Previsões Redes Neurais GRU", fontsize=16, fontweight="bold")
plt.xlabel("Data", fontsize=12, fontweight="bold")
plt.ylabel("Valor das Ações", fontsize=12, fontweight="bold")
plt.legend()
plt.show()

# %% [markdown]
# ### Salvamento dos objetos que serão necessários na aplicação web

# %%
previsoes_teste = pd.DataFrame({ "Valores Reais": y_test.flatten(), "Previsões": y_pred.flatten()}, index=index_test)
previsoes_teste
# Out:
#             Valores Reais   Previsões
# Date
# 2024-12-20     421.059998  444.467926
# 2024-12-23     430.600006  432.493256
# 2024-12-24     462.279999  435.610138
# 2024-12-26     454.130005  458.032684
# 2024-12-27     431.660004  460.343506
# ...                   ...         ...
# 2025-03-18     225.309998  241.860382
# 2025-03-19     235.860001  229.102005
# 2025-03-20     236.259995  238.009644
# 2025-03-21     248.710007  239.219254
# 2025-03-24     278.390015  250.671265
#
# [62 rows x 2 columns]

# %%
previsoes_teste.to_csv("dados_teste.csv")

# %%
modelo_gru.save("Modelo_treinado.keras")

# %%
dump(scaler, "scaler.joblib")
# Out:
# ['scaler.joblib']
